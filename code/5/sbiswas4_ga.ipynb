# %% [markdown]
# # Genetic Algorithm Workshop

# %% [markdown]
# In this workshop we will code up a genetic algorithm for a simple mathematical optimization problem.
#
# Genetic Algorithm is a
# * Meta-heuristic
# * Inspired by Natural Selection
# * Traditionally works on binary data. Can be adopted for other data types as well.
#
# You can find an example illustrating GA below
# ![](https://github.com/timm/sbse14/wiki/etc/img/ga.jpg)

# %%
# %matplotlib inline
# All the imports
from __future__ import print_function, division
from math import *
import random
import sys
import matplotlib.pyplot as plt


# TODO 1: Enter your unity ID here 
__author__ = "sbiswas4"

class O:
    """
    Basic Class which
        - Helps dynamic updates
        - Pretty Prints
    """
    def __init__(self, **kwargs):
        self.has().update(**kwargs)
    def has(self):
        return self.__dict__
    def update(self, **kwargs):
        self.has().update(kwargs)
        return self
    def __repr__(self):
        show = [':%s %s' % (k, self.has()[k]) 
                for k in sorted(self.has().keys()) 
                if k[0] is not "_"]
        txt = ' '.join(show)
        if len(txt) > 60:
            show = map(lambda x: '\t' + x + '\n', show)
        return '{' + ' '.join(show) + '}'
    
print("Unity ID: ", __author__)
# Out:
# Unity ID:  sbiswas4

# %% [markdown]
# ### The optimization problem
# The problem we are considering is a mathematical one
# <img src="cone.png" width=500px/>
#
# **Decisions**: *r* in [0, 10] cm; *h* in [0, 20] cm
#
# **Objectives**: minimize *S*, *T*
#
# **Constraints**: *V* > 200cm<sup>3</sup>

# %%
# Few Utility functions
def say(*lst):
    """
    Print whithout going to new line
    """
    print(*lst, end="")
    sys.stdout.flush()

def random_value(low, high, decimals=2):
    """
    Generate a random number between low and high. 
    decimals incidicate number of decimal places
    """
    return round(random.uniform(low, high),decimals)

def gt(a, b): return a > b

def lt(a, b): return a < b

def shuffle(lst):
    """
    Shuffle a list
    """
    random.shuffle(lst)
    return lst

class Decision(O):
    """
    Class indicating Decision of a problem
    """
    def __init__(self, name, low, high):
        """
        @param name: Name of the decision
        @param low: minimum value
        @param high: maximum value
        """
        O.__init__(self, name=name, low=low, high=high)
        
class Objective(O):
    """
    Class indicating Objective of a problem
    """
    def __init__(self, name, do_minimize=True):
        """
        @param name: Name of the objective
        @param do_minimize: Flag indicating if objective has to be minimized or maximized
        """
        O.__init__(self, name=name, do_minimize=do_minimize)

class Point(O):
    """
    Represents a member of the population
    """
    def __init__(self, decisions):
        O.__init__(self)
        self.decisions = decisions
        self.objectives = None
        
    def __hash__(self):
        return hash(tuple(self.decisions))
    
    def __eq__(self, other):
        return self.decisions == other.decisions
    
    def clone(self):
        new = Point(self.decisions)
        new.objectives = self.objectives
        return new

class Problem(O):
    """
    Class representing the cone problem.
    """
    def __init__(self):
        O.__init__(self)
        # TODO 2: Code up decisions and objectives below for the problem
        # using the auxilary classes provided above.
        self.decisions = [Decision('r', 0, 10), Decision('h', 0, 20)]
        #T= Total surface area and S= Curved SUrface area
        self.objectives = [Objective('S'), Objective('T')]
        
    @staticmethod
    def evaluate(point):
        [r, h] = point.decisions
        # TODO 3: Evaluate the objectives S and T for the point.
        base= pi*r*r
        slant= sqrt((r**2)+(h**2))
        S=pi*r*slant  #lateral surface area
        T=base+S       #total surface area
        point.objectives=[S,T]
        return point.objectives
    
    @staticmethod
    def is_valid(point):
#         print (point)
        if point is None:
            [r, h]= [0.9,15.8]
        else:
            [r, h] = point.decisions
        # TODO 4: Check if the point has valid decisions
        r=float(r)
        he=float(h)
        Volume=(pi*r*r*h)/3
        if Volume>200:
            return True
        return False
    
    
    def generate_one(self):
        # TODO 5: Generate a valid instance of Point.
        [r,h] = self.decisions     
        p=Point([random_value(r.low,r.high),random_value(h.low,h.high)])      
#         if Problem.is_valid(p):
        while not Problem.is_valid(p):
            p.decisions=[random_value(r.low,r.high),random_value(h.low,h.high)]
        return p
        
        

cone = Problem()
point = cone.generate_one()
cone.evaluate(point)
print(point)
# Out:
# {	:decisions [8.55, 2.74]
#  	:objectives [241.1630220177257, 470.8212989767736]
# }

# %% [markdown]
# Great. Now that the class and its basic methods is defined, we move on to code up the GA.
# ### Population
# First up is to create an initial population.

# %%
def populate(problem, size):
    population = []
    # TODO 6: Create a list of points of length 'size'
    for i in range(size):
        population.append(problem.generate_one())
    return population

# or if ur python OBSESSED
#        return [problem.generate_one() for _ in xrange(size)]

pop=populate(cone, 5)
# print(pop)

# %% [markdown]
# ### Crossover
# We perform a single point crossover between two points

# %%
def crossover(mom, dad):
    # TODO 7: Create a new point which contains decisions from 
    # the first half of mom and second half of dad
    half_pt= len(mom.decisions)//2
    cross_o=mom.decisions[:half_pt]+dad.decisions[half_pt:]
    return Point(cross_o)

pop=populate(cone,5)
crossover(pop[0], pop[1])
# Out:
# {:decisions [5.33, 10.38] :objectives None}

# %% [markdown]
# ### Mutation
# Randomly change a decision such that

# %%
def mutate(problem, point, mutation_rate=0.01):
    # TODO 8: Iterate through all the decisions in the problem
    # and if the probability is less than mutation rate
    # change the decision(randomly set it between its max and min).
    for i in range(len(problem.decisions)):
        if random.random()<mutation_rate:
            point.decisions[i] = random_value(problem.decisions[i].low, problem.decisions[i].high)
    print (point)
    
mutate(cone,point)
# Out:
# {	:decisions [8.55, 2.74]
#  	:objectives [241.1630220177257, 470.8212989767736]
# }

# %% [markdown]
# ### Fitness Evaluation
# To evaluate fitness between points we use binary domination. Binary Domination is defined as follows:
# * Consider two points one and two.
# * For every objective **o** and **t** in **one** and **two**, **o** <= **t**
# * Atleast one objective **o** and **t** in **one** and **two**, **o** < **t**
#
# **Note**: Binary Domination is not the best method to evaluate fitness but due to its simplicity we choose to use it for this workshop.

# %%
def bdom(problem, one, two):
    """
    Return if one dominates two
    """
    objs_one = problem.evaluate(one)
    objs_two = problem.evaluate(two)
    dominates = False
    # TODO 9: Return True/False based on the definition
    # of bdom above.
    for i in range(len(objs_one)):
        if objs_two[i]<objs_one[i]:
            return False
        elif objs_one[i] <= objs_two[i]:
            return True
        
    if dominates:
        return True
    return False

bdom(cone, pop[0],pop[1])
# Out:
# True

# %% [markdown]
# ### Fitness and Elitism
#
# In this workshop we will count the number of points of the population P dominated by a point A as the fitness of point A. This is a very naive measure of fitness since we are using binary domination.
#
# Few prominent alternate methods are
# 1. [Continuous Domination](http://www.tik.ee.ethz.ch/sop/publicationListFiles/zk2004a.pdf) - Section 3.1
# 2. [Non-dominated Sort](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=996017)
# 3. [Non-dominated Sort + Niching](http://www.egr.msu.edu/~kdeb/papers/k2012009.pdf)
#
# **Elitism**: Sort points with respect to the fitness and select the top points.

# %%
def fitness(problem, population, point):
    dominates = 0
    # TODO 10: Evaluate fitness of a point.
    # For this workshop define fitness of a point 
    # as the number of points dominated by it.
    # For example point dominates 5 members of population,
    # then fitness of point is 5.
    for i in population:
        if (i !=point) and bdom(problem,point,i):
            dominates+=1
        point.fitness = dominates
        return dominates

def elitism(problem, population, retain_size):
    # TODO 11: Sort the population with respect to the fitness
    # of the points and return the top 'retain_size' points of the population
    
#     return population[:retain_size]

    population = sorted(population, key=lambda x: fitness(problem, population, x), reverse=True)
    return population[:retain_size]

# %% [markdown]
# ### Putting it all together and making the GA

# %%
def ga(pop_size = 100, gens = 250):
    problem = Problem()
    population = populate(problem, pop_size)
    [problem.evaluate(point) for point in population]
    initial_population = [point.clone() for point in population]
    gen = 0 
    while gen < gens:
        say(".")
        children = []
        for _ in range(pop_size):
            mom = random.choice(population)
            dad = random.choice(population)
            while (mom == dad):
                dad = random.choice(population)
            child = mutate(problem, crossover(mom, dad))
            if problem.is_valid(child) and child not in population+children:
                children.append(child)
        population += children
        population = elitism(problem, population, pop_size)
        gen += 1
    print("")
    return initial_population, population

# %% [markdown]
# ### Visualize
# Lets plot the initial population with respect to the final frontier.

# %%
def plot_pareto(initial, final):
    initial_objs = [point.objectives for point in initial]
    final_objs = [point.objectives for point in final]
    initial_x = [i[0] for i in initial_objs]
    initial_y = [i[1] for i in initial_objs]
    final_x = [i[0] for i in final_objs]
    final_y = [i[1] for i in final_objs]
    plt.scatter(initial_x, initial_y, color='b', marker='+', label='initial')
    plt.scatter(final_x, final_y, color='r', marker='o', label='final')
    plt.title("Scatter Plot between initial and final population of GA")
    plt.ylabel("Total Surface Area(T)")
    plt.xlabel("Curved Surface Area(S)")
    plt.legend(loc=9, bbox_to_anchor=(0.5, -0.175), ncol=2)
    plt.show()

# %%
initial, final = ga()
plot_pareto(initial, final)
# Out:
# .{:decisions [9.78, 17.46] :objectives None}
# {:decisions [5.13, 7.56] :objectives None}
# {:decisions [9.72, 13.11] :objectives None}
# {:decisions [7.57, 17.68] :objectives None}
# {:decisions [9.37, 8.72] :objectives None}
# {:decisions [6.66, 3.45] :objectives None}
# {:decisions [5.13, 18.87] :objectives None}
# {:decisions [6.35, 17.0] :objectives None}
# {:decisions [5.13, 5.91] :objectives None}
# {:decisions [8.24, 16.33] :objectives None}
# {:decisions [5.72, 17.48] :objectives None}
# {:decisions [8.82, 9.24] :objectives None}
# {:decisions [6.62, 16.72] :objectives None}
# {:decisions [7.45, 14.67] :objectives None}
# {:decisions [7.45, 15.11] :objectives None}
# {:decisions [9.26, 13.11] :objectives None}
# {:decisions [9.78, 15.81] :objectives None}
# {:decisions [4.76, 14.48] :objectives None}
# {:decisions [4.3, 16.72] :objectives None}
# {:decisions [6.61, 19.59] :objectives None}
# {:decisions [9.15, 14.67] :objectives None}
# {:decisions [5.72, 5.93] :objectives None}
# {:decisions [8.82, 4.23] :objectives None}
# {:decisions [7.81, 15.11] :objectives None}
# {:decisions [3.97, 5.91] :objectives None}
# {:decisions [4.3, 14.7] :objectives None}
# {:decisions [8.98, 15.53] :objectives None}
# {:decisions [6.62, 12.95] :objectives None}
# {:decisions [8.95, 3.47] :objectives None}
# {:decisions [4.76, 13.77] :objectives None}
# {:decisions [8.24, 12.58] :objectives None}
# {:decisions [9.85, 7.47] :objectives None}
# {:decisions [9.54, 7.47] :objectives None}
# {:decisions [9.23, 5.91] :objectives None}
# {:decisions [8.85, 12.38] :objectives None}
# {:decisions [9.26, 17.48] :objectives None}
# {:decisions [8.02, 16.55] :objectives None}
# {:decisions [6.87, 18.04] :objectives None}
# {:decisions [8.98, 16.72] :objectives None}
# {:decisions [5.57, 2.95] :objectives None}
# {:decisions [9.26, 15.17] :objectives None}
# {:decisions [7.3, 15.81] :objectives None}
# {:decisions [4.31, 17.47] :objectives None}
# {:decisions [6.61, 19.71] :objectives None}
# {:decisions [9.0, 18.22] :objectives None}
# {:decisions [6.42, 8.53] :objectives None}
# {:decisions [8.82, 17.48] :objectives None}
# {:decisions [7.57, 8.53] :objectives None}
# {:decisions [7.98, 17.48] :objectives None}
# {:decisions [6.19, 16.04] :objectives None}
# {:decisions [6.72, 16.01] :objectives None}
# {:decisions [6.35, 19.0] :objectives None}
# {:decisions [9.26, 16.33] :objectives None}
# {:decisions [9.54, 9.57] :objectives None}
# {:decisions [5.54, 14.16] :objectives None}
# {:decisions [9.15, 11.77] :objectives None}
# {:decisions [6.87, 19.85] :objectives None}
# {:decisions [5.54, 18.11] :objectives None}
# {:decisions [7.81, 12.38] :objectives None}
# {:decisions [9.12, 11.75] :objectives None}
# {:decisions [5.66, 17.47] :objectives None}
# {:decisions [9.15, 10.85] :objectives None}
# {:decisions [7.98, 9.24] :objectives None}
# {:decisions [8.82, 17.47] :objectives None}
# {:decisions [7.57, 17.0] :objectives None}
# {:decisions [8.98, 7.76] :objectives None}
# {:decisions [5.57, 10.35] :objectives None}
# {:decisions [3.92, 7.56] :objectives None}
# {:decisions [5.57, 17.44] :objectives None}
# {:decisions [6.19, 19.0] :objectives None}
# {:decisions [7.03, 17.48] :objectives None}
# {:decisions [9.66, 13.11] :objectives None}
# {:decisions [7.28, 8.72] :objectives None}
# {:decisions [9.78, 7.76] :objectives None}
# {:decisions [3.92, 2.95] :objectives None}
# {:decisions [4.31, 10.97] :objectives None}
# {:decisions [8.98, 12.57] :objectives None}
# {:decisions [7.81, 12.57] :objectives None}
# {:decisions [6.61, 14.39] :objectives None}
# {:decisions [8.82, 18.95] :objectives None}
# {:decisions [7.95, 7.76] :objectives None}
# {:decisions [6.64, 5.79] :objectives None}
# {:decisions [8.02, 5.79] :objectives None}
# {:decisions [5.94, 18.05] :objectives None}
# {:decisions [8.85, 16.33] :objectives None}
# {:decisions [1.42, 16.01] :objectives None}
# {:decisions [4.3, 10.11] :objectives None}
# {:decisions [4.78, 19.89] :objectives None}
# {:decisions [8.95, 14.81] :objectives None}
# {:decisions [7.61, 16.55] :objectives None}
# {:decisions [8.98, 19.71] :objectives None}
# {:decisions [4.76, 10.6] :objectives None}
# {:decisions [7.8, 7.14] :objectives None}
# {:decisions [6.27, 18.22] :objectives None}
# {:decisions [4.99, 4.23] :objectives None}
# {:decisions [7.81, 7.92] :objectives None}
# {:decisions [6.66, 18.11] :objectives None}
# {:decisions [9.43, 7.93] :objectives None}
# {:decisions [6.27, 14.7] :objectives None}
# {:decisions [8.02, 15.17] :objectives None}
# .{:decisions [6.64, 5.43] :objectives None}
# {:decisions [6.05, 17.42] :objectives None}
# {:decisions [8.0, 7.92] :objectives None}
# {:decisions [5.37, 7.5] :objectives None}
# {:decisions [9.44, 18.84] :objectives None}
# {:decisions [7.81, 16.72] :objectives None}
# {:decisions [7.8, 16.72] :objectives None}
# {:decisions [4.47, 7.0] :objectives None}
# {:decisions [2.92, 10.9] :objectives None}
# {:decisions [4.88, 16.04] :objectives None}
# {:decisions [9.0, 10.35] :objectives None}
# {:decisions [9.85, 17.49] :objectives None}
# {:decisions [7.28, 17.49] :objectives None}
# {:decisions [7.57, 2.95] :objectives None}
# {:decisions [5.13, 10.85] :objectives None}
# {:decisions [9.15, 18.87] :objectives None}
# {:decisions [9.66, 16.04] :objectives None}
# {:decisions [8.24, 17.47] :objectives None}
# {:decisions [8.52, 12.58] :objectives None}
# {:decisions [9.85, 15.4] :objectives None}
# {:decisions [5.54, 5.61] :objectives None}
# {:decisions [8.85, 16.01] :objectives None}
# {:decisions [4.3, 17.0] :objectives None}
# {:decisions [8.17, 14.7] :objectives None}
# {:decisions [7.3, 16.55] :objectives None}
# {:decisions [7.61, 17.42] :objectives None}
# {:decisions [5.13, 18.01] :objectives None}
# {:decisions [7.81, 9.57] :objectives None}
# {:decisions [5.08, 13.39] :objectives None}
# {:decisions [5.5, 10.9] :objectives None}
# {:decisions [8.0, 12.95] :objectives None}
# {:decisions [4.31, 12.47] :objectives None}
# {:decisions [5.5, 2.95] :objectives None}
# {:decisions [7.32, 16.81] :objectives None}
# {:decisions [7.98, 8.53] :objectives None}
# {:decisions [9.0, 7.56] :objectives None}
# {:decisions [9.15, 14.75] :objectives None}
# {:decisions [6.35, 17.44] :objectives None}
# {:decisions [9.72, 8.53] :objectives None}
# {:decisions [7.71, 14.16] :objectives None}
# {:decisions [9.0, 18.87] :objectives None}
# {:decisions [6.61, 18.11] :objectives None}
# {:decisions [9.85, 15.98] :objectives None}
# {:decisions [3.69, 14.75] :objectives None}
# {:decisions [7.98, 16.33] :objectives None}
# {:decisions [6.82, 14.67] :objectives None}
# {:decisions [5.05, 11.77] :objectives None}
# {:decisions [9.0, 14.39] :objectives None}
# {:decisions [9.29, 16.01] :objectives None}
# {:decisions [7.61, 17.49] :objectives None}
# {:decisions [7.74, 17.46] :objectives None}
# {:decisions [4.94, 7.93] :objectives None}
# {:decisions [7.25, 18.84] :objectives None}
# {:decisions [6.5, 18.01] :objectives None}
# {:decisions [4.31, 10.71] :objectives None}
# {:decisions [5.13, 16.72] :objectives None}
# {:decisions [9.43, 18.84] :objectives None}
# {:decisions [6.61, 12.38] :objectives None}
# {:decisions [6.19, 18.04] :objectives None}
# {:decisions [6.51, 5.61] :objectives None}
# {:decisions [7.56, 7.5] :objectives None}
# {:decisions [8.53, 16.33] :objectives None}
# {:decisions [7.61, 16.04] :objectives None}
# {:decisions [7.45, 18.22] :objectives None}
# {:decisions [3.69, 16.55] :objectives None}
# {:decisions [5.94, 15.98] :objectives None}
# {:decisions [7.95, 17.68] :objectives None}
# {:decisions [7.25, 17.55] :objectives None}
# {:decisions [6.62, 17.47] :objectives None}
# {:decisions [9.85, 10.85] :objectives None}
# {:decisions [6.87, 18.01] :objectives None}
# {:decisions [7.81, 15.4] :objectives None}
# {:decisions [5.94, 15.17] :objectives None}
# {:decisions [9.15, 17.55] :objectives None}
# {:decisions [8.95, 17.55] :objectives None}
# {:decisions [7.81, 13.77] :objectives None}
# {:decisions [4.47, 18.11] :objectives None}
# {:decisions [8.0, 13.84] :objectives None}
# {:decisions [6.66, 14.75] :objectives None}
# {:decisions [7.81, 5.61] :objectives None}
# {:decisions [4.47, 12.95] :objectives None}
# {:decisions [5.54, 17.73] :objectives None}
# {:decisions [4.62, 13.39] :objectives None}
# {:decisions [6.28, 18.22] :objectives None}
# {:decisions [7.56, 17.53] :objectives None}
# {:decisions [6.87, 5.7] :objectives None}
# {:decisions [6.66, 10.6] :objectives None}
# {:decisions [8.02, 5.81] :objectives None}
# {:decisions [9.26, 17.55] :objectives None}
# {:decisions [8.17, 6.49] :objectives None}
# {:decisions [5.41, 11.75] :objectives None}
# {:decisions [8.32, 12.58] :objectives None}
# {:decisions [8.17, 14.75] :objectives None}
# {:decisions [8.95, 18.09] :objectives None}
# {:decisions [8.0, 17.73] :objectives None}
# {:decisions [4.76, 16.01] :objectives None}
# {:decisions [8.32, 7.5] :objectives None}
# {:decisions [4.88, 7.92] :objectives None}
# {:decisions [6.92, 14.33] :objectives None}
# {:decisions [3.92, 14.86] :objectives None}
# .{:decisions [5.74, 12.47] :objectives None}
# {:decisions [6.61, 17.49] :objectives None}
# {:decisions [4.78, 14.81] :objectives None}
# {:decisions [5.13, 7.14] :objectives None}
# {:decisions [5.5, 16.33] :objectives None}
# {:decisions [9.66, 18.87] :objectives None}
# {:decisions [6.82, 16.01] :objectives None}
# {:decisions [8.19, 6.8] :objectives None}
# {:decisions [7.61, 7.93] :objectives None}
# {:decisions [7.71, 3.45] :objectives None}
# {:decisions [7.08, 12.38] :objectives None}
# {:decisions [9.85, 8.23] :objectives None}
# {:decisions [5.54, 7.5] :objectives None}
# {:decisions [3.97, 5.51] :objectives None}
# {:decisions [6.08, 5.7] :objectives None}
# {:decisions [4.94, 6.8] :objectives None}
# {:decisions [6.87, 10.11] :objectives None}
# {:decisions [7.71, 7.5] :objectives None}
# {:decisions [5.37, 19.0] :objectives None}
# {:decisions [8.52, 11.77] :objectives None}
# {:decisions [4.88, 10.11] :objectives None}
# {:decisions [4.94, 12.65] :objectives None}
# {:decisions [5.08, 2.95] :objectives None}
# {:decisions [9.26, 13.77] :objectives None}
# {:decisions [9.23, 19.89] :objectives None}
# {:decisions [3.92, 18.09] :objectives None}
# {:decisions [7.98, 13.84] :objectives None}
# {:decisions [8.52, 13.11] :objectives None}
# {:decisions [6.05, 10.35] :objectives None}
# {:decisions [8.53, 6.8] :objectives None}
# {:decisions [6.87, 17.46] :objectives None}
# {:decisions [7.28, 14.81] :objectives None}
# {:decisions [4.23, 9.24] :objectives None}
# {:decisions [6.72, 17.0] :objectives None}
# {:decisions [9.26, 15.98] :objectives None}
# {:decisions [7.81, 7.93] :objectives None}
# {:decisions [9.66, 18.09] :objectives None}
# {:decisions [5.08, 7.0] :objectives None}
# {:decisions [3.69, 14.75] :objectives None}
# {:decisions [6.92, 18.01] :objectives None}
# {:decisions [6.28, 19.85] :objectives None}
# {:decisions [8.32, 14.48] :objectives None}
# {:decisions [6.27, 17.49] :objectives None}
# {:decisions [6.61, 14.16] :objectives None}
# {:decisions [4.99, 7.0] :objectives None}
# {:decisions [6.62, 17.53] :objectives None}
# {:decisions [9.78, 10.9] :objectives None}
# {:decisions [7.8, 9.24] :objectives None}
# {:decisions [7.81, 18.22] :objectives None}
# {:decisions [5.94, 18.22] :objectives None}
# {:decisions [7.3, 7.92] :objectives None}
# {:decisions [5.97, 17.46] :objectives None}
# {:decisions [9.72, 15.81] :objectives None}
# {:decisions [9.0, 3.47] :objectives None}
# {:decisions [5.37, 15.11] :objectives None}
# {:decisions [9.54, 17.49] :objectives None}
# {:decisions [7.57, 10.97] :objectives None}
# {:decisions [7.45, 10.11] :objectives None}
# {:decisions [5.72, 18.87] :objectives None}
# {:decisions [5.94, 18.87] :objectives None}
# {:decisions [8.0, 19.69] :objectives None}
# {:decisions [7.74, 14.67] :objectives None}
# {:decisions [8.32, 15.09] :objectives None}
# {:decisions [9.78, 19.59] :objectives None}
# {:decisions [7.71, 14.7] :objectives None}
# {:decisions [7.81, 16.55] :objectives None}
# {:decisions [7.02, 11.42] :objectives None}
# {:decisions [7.98, 19.71] :objectives None}
# {:decisions [3.89, 13.84] :objectives None}
# {:decisions [7.81, 5.93] :objectives None}
# {:decisions [4.23, 16.04] :objectives None}
# {:decisions [6.92, 10.9] :objectives None}
# {:decisions [8.82, 19.71] :objectives None}
# {:decisions [8.64, 13.86] :objectives None}
# {:decisions [4.31, 10.97] :objectives None}
# {:decisions [7.3, 18.01] :objectives None}
# {:decisions [8.52, 15.09] :objectives None}
# {:decisions [8.0, 9.57] :objectives None}
# {:decisions [8.53, 18.04] :objectives None}
# {:decisions [7.25, 7.92] :objectives None}
# {:decisions [6.62, 19.69] :objectives None}
# {:decisions [4.78, 19.89] :objectives None}
# {:decisions [7.81, 15.11] :objectives None}
# {:decisions [9.78, 2.95] :objectives None}
# {:decisions [9.37, 5.61] :objectives None}
# {:decisions [8.98, 18.04] :objectives None}
# {:decisions [5.94, 17.49] :objectives None}
# {:decisions [5.97, 7.93] :objectives None}
# {:decisions [8.95, 17.68] :objectives None}
# {:decisions [7.81, 17.0] :objectives None}
# {:decisions [8.32, 15.17] :objectives None}
# {:decisions [8.64, 10.9] :objectives None}
# {:decisions [7.57, 17.55] :objectives None}
# {:decisions [8.95, 7.56] :objectives None}
# {:decisions [9.54, 9.57] :objectives None}
# {:decisions [7.32, 18.11] :objectives None}
# {:decisions [5.08, 2.95] :objectives None}
# {:decisions [8.02, 15.53] :objectives None}
# {:decisions [4.31, 18.01] :objectives None}
# {:decisions [7.45, 16.01] :objectives None}
# .{:decisions [7.25, 8.72] :objectives None}
# {:decisions [6.61, 18.95] :objectives None}
# {:decisions [9.72, 13.86] :objectives None}
# {:decisions [7.95, 15.17] :objectives None}
# {:decisions [7.28, 8.16] :objectives None}
# {:decisions [4.23, 17.47] :objectives None}
# {:decisions [7.74, 18.09] :objectives None}
# {:decisions [7.28, 16.81] :objectives None}
# {:decisions [8.95, 5.43] :objectives None}
# {:decisions [8.64, 13.11] :objectives None}
# {:decisions [7.98, 18.01] :objectives None}
# {:decisions [5.13, 11.75] :objectives None}
# {:decisions [8.17, 5.79] :objectives None}
# {:decisions [8.24, 9.24] :objectives None}
# {:decisions [5.57, 14.67] :objectives None}
# {:decisions [8.82, 5.43] :objectives None}
# {:decisions [9.72, 15.09] :objectives None}
# {:decisions [9.26, 16.01] :objectives None}
# {:decisions [7.57, 19.85] :objectives None}
# {:decisions [6.87, 19.71] :objectives None}
# {:decisions [6.66, 5.51] :objectives None}
# {:decisions [6.92, 7.93] :objectives None}
# {:decisions [7.25, 19.0] :objectives None}
# {:decisions [9.0, 14.33] :objectives None}
# {:decisions [4.3, 15.11] :objectives None}
# {:decisions [3.92, 14.75] :objectives None}
# {:decisions [8.02, 12.95] :objectives None}
# {:decisions [7.95, 17.47] :objectives None}
# {:decisions [6.92, 11.75] :objectives None}
# {:decisions [8.82, 10.9] :objectives None}
# {:decisions [9.05, 7.0] :objectives None}
# {:decisions [6.66, 18.09] :objectives None}
# {:decisions [5.94, 10.9] :objectives None}
# {:decisions [4.23, 3.45] :objectives None}
# {:decisions [6.27, 18.05] :objectives None}
# {:decisions [5.05, 18.04] :objectives None}
# {:decisions [9.85, 14.33] :objectives None}
# {:decisions [4.78, 5.51] :objectives None}
# {:decisions [6.35, 19.59] :objectives None}
# {:decisions [6.08, 7.92] :objectives None}
# {:decisions [9.72, 19.59] :objectives None}
# {:decisions [8.98, 5.7] :objectives None}
# {:decisions [3.97, 16.04] :objectives None}
# {:decisions [6.92, 17.73] :objectives None}
# {:decisions [9.26, 18.87] :objectives None}
# {:decisions [4.65, 2.72] :objectives None}
# {:decisions [4.94, 10.11] :objectives None}
# {:decisions [9.12, 7.92] :objectives None}
# {:decisions [5.13, 12.65] :objectives None}
# {:decisions [7.45, 12.38] :objectives None}
# {:decisions [6.19, 12.47] :objectives None}
# {:decisions [6.05, 15.53] :objectives None}
# {:decisions [4.94, 9.57] :objectives None}
# {:decisions [6.27, 17.48] :objectives None}
# {:decisions [4.78, 14.33] :objectives None}
# {:decisions [3.63, 7.76] :objectives None}
# {:decisions [6.28, 10.97] :objectives None}
# {:decisions [5.37, 6.49] :objectives None}
# {:decisions [8.0, 17.42] :objectives None}
# {:decisions [6.64, 19.85] :objectives None}
# {:decisions [5.72, 8.53] :objectives None}
# {:decisions [5.37, 16.04] :objectives None}
# {:decisions [6.5, 14.7] :objectives None}
# {:decisions [8.43, 17.73] :objectives None}
# {:decisions [7.95, 17.46] :objectives None}
# {:decisions [9.44, 10.85] :objectives None}
# {:decisions [8.98, 10.9] :objectives None}
# {:decisions [5.13, 17.46] :objectives None}
# {:decisions [4.23, 18.05] :objectives None}
# {:decisions [8.17, 12.95] :objectives None}
# {:decisions [9.26, 8.72] :objectives None}
# {:decisions [6.61, 10.85] :objectives None}
# {:decisions [7.45, 16.72] :objectives None}
# {:decisions [6.05, 15.09] :objectives None}
# {:decisions [5.08, 7.92] :objectives None}
# {:decisions [4.31, 13.39] :objectives None}
# {:decisions [6.19, 14.48] :objectives None}
# {:decisions [6.87, 9.24] :objectives None}
# {:decisions [9.0, 5.43] :objectives None}
# {:decisions [5.13, 15.53] :objectives None}
# {:decisions [8.17, 16.33] :objectives None}
# {:decisions [4.94, 19.0] :objectives None}
# {:decisions [6.87, 13.86] :objectives None}
# {:decisions [7.95, 7.14] :objectives None}
# {:decisions [7.25, 14.33] :objectives None}
# {:decisions [6.64, 16.33] :objectives None}
# {:decisions [7.45, 18.09] :objectives None}
# {:decisions [8.43, 12.58] :objectives None}
# {:decisions [9.23, 7.47] :objectives None}
# {:decisions [7.28, 17.0] :objectives None}
# {:decisions [8.98, 7.0] :objectives None}
# {:decisions [7.8, 13.11] :objectives None}
# {:decisions [6.19, 14.33] :objectives None}
# {:decisions [4.78, 16.81] :objectives None}
# {:decisions [3.63, 2.95] :objectives None}
# {:decisions [4.94, 18.87] :objectives None}
# {:decisions [9.0, 15.98] :objectives None}
# {:decisions [5.54, 16.04] :objectives None}
# {:decisions [7.74, 12.65] :objectives None}
# {:decisions [6.64, 9.24] :objectives None}
# .{:decisions [3.97, 17.73] :objectives None}
# {:decisions [5.72, 17.42] :objectives None}
# {:decisions [8.17, 17.73] :objectives None}
# {:decisions [5.13, 14.75] :objectives None}
# {:decisions [6.82, 3.47] :objectives None}
# {:decisions [8.82, 17.42] :objectives None}
# {:decisions [4.99, 19.85] :objectives None}
# {:decisions [3.63, 11.75] :objectives None}
# {:decisions [8.02, 10.6] :objectives None}
# {:decisions [6.82, 10.85] :objectives None}
# {:decisions [8.02, 11.75] :objectives None}
# {:decisions [6.28, 18.87] :objectives None}
# {:decisions [7.28, 17.46] :objectives None}
# {:decisions [6.64, 9.57] :objectives None}
# {:decisions [5.41, 18.05] :objectives None}
# {:decisions [3.89, 17.48] :objectives None}
# {:decisions [9.12, 6.8] :objectives None}
# {:decisions [8.85, 5.93] :objectives None}
# {:decisions [9.43, 10.11] :objectives None}
# {:decisions [9.23, 16.01] :objectives None}
# {:decisions [9.54, 18.09] :objectives None}
# {:decisions [4.65, 6.3] :objectives None}
# {:decisions [5.08, 18.05] :objectives None}
# {:decisions [7.71, 15.81] :objectives None}
# {:decisions [0.99, 12.57] :objectives None}
# {:decisions [8.17, 12.58] :objectives None}
# {:decisions [7.61, 18.09] :objectives None}
# {:decisions [7.32, 17.49] :objectives None}
# {:decisions [8.19, 10.35] :objectives None}
# {:decisions [8.19, 19.85] :objectives None}
# {:decisions [4.65, 17.48] :objectives None}
# {:decisions [4.62, 14.86] :objectives None}
# {:decisions [8.82, 3.45] :objectives None}
# {:decisions [8.85, 10.35] :objectives None}
# {:decisions [6.28, 7.92] :objectives None}
# {:decisions [7.56, 17.46] :objectives None}
# {:decisions [8.82, 19.59] :objectives None}
# {:decisions [6.66, 12.57] :objectives None}
# {:decisions [8.02, 14.7] :objectives None}
# {:decisions [8.0, 17.46] :objectives None}
# {:decisions [3.69, 12.95] :objectives None}
# {:decisions [6.62, 13.39] :objectives None}
# {:decisions [7.95, 13.11] :objectives None}
# {:decisions [9.26, 18.22] :objectives None}
# {:decisions [5.13, 14.75] :objectives None}
# {:decisions [6.35, 19.0] :objectives None}
# {:decisions [9.15, 18.84] :objectives None}
# {:decisions [4.23, 18.01] :objectives None}
# {:decisions [6.64, 17.46] :objectives None}
# {:decisions [6.05, 17.55] :objectives None}
# {:decisions [7.81, 19.71] :objectives None}
# {:decisions [9.43, 14.48] :objectives None}
# {:decisions [7.32, 2.72] :objectives None}
# {:decisions [5.41, 14.7] :objectives None}
# {:decisions [7.25, 14.75] :objectives None}
# {:decisions [7.32, 5.91] :objectives None}
# {:decisions [9.44, 17.46] :objectives None}
# {:decisions [8.82, 16.55] :objectives None}
# {:decisions [3.92, 18.01] :objectives None}
# {:decisions [6.82, 14.86] :objectives None}
# {:decisions [7.74, 12.65] :objectives None}
# {:decisions [7.28, 4.23] :objectives None}
# {:decisions [5.94, 10.6] :objectives None}
# {:decisions [5.57, 7.92] :objectives None}
# {:decisions [8.19, 13.84] :objectives None}
# {:decisions [7.8, 6.3] :objectives None}
# {:decisions [7.45, 14.75] :objectives None}
# {:decisions [6.61, 5.79] :objectives None}
# {:decisions [4.53, 14.81] :objectives None}
# {:decisions [8.32, 18.11] :objectives None}
# {:decisions [9.12, 3.68] :objectives None}
# {:decisions [5.94, 18.22] :objectives None}
# {:decisions [4.62, 16.04] :objectives None}
# {:decisions [9.78, 5.43] :objectives None}
# {:decisions [5.97, 13.77] :objectives None}
# {:decisions [8.64, 5.43] :objectives None}
# {:decisions [9.26, 5.51] :objectives None}
# {:decisions [8.98, 15.81] :objectives None}
# {:decisions [7.32, 18.95] :objectives None}
# {:decisions [6.66, 8.16] :objectives None}
# {:decisions [5.97, 18.01] :objectives None}
# {:decisions [6.08, 15.4] :objectives None}
# {:decisions [7.81, 12.38] :objectives None}
# {:decisions [8.0, 11.77] :objectives None}
# {:decisions [9.23, 10.35] :objectives None}
# {:decisions [6.82, 7.0] :objectives None}
# {:decisions [9.54, 16.33] :objectives None}
# {:decisions [7.61, 18.87] :objectives None}
# {:decisions [7.81, 17.73] :objectives None}
# {:decisions [4.88, 19.0] :objectives None}
# {:decisions [9.37, 19.89] :objectives None}
# {:decisions [9.85, 18.01] :objectives None}
# {:decisions [4.99, 4.1] :objectives None}
# {:decisions [5.37, 14.39] :objectives None}
# {:decisions [9.7, 13.77] :objectives None}
# {:decisions [4.88, 14.75] :objectives None}
# {:decisions [9.23, 19.85] :objectives None}
# {:decisions [8.53, 2.95] :objectives None}
# {:decisions [9.43, 16.81] :objectives None}
# {:decisions [7.98, 14.7] :objectives None}
# .{:decisions [6.5, 17.53] :objectives None}
# {:decisions [5.05, 13.11] :objectives None}
# {:decisions [9.37, 13.39] :objectives None}
# {:decisions [4.99, 16.33] :objectives None}
# {:decisions [6.66, 18.95] :objectives None}
# {:decisions [4.23, 18.04] :objectives None}
# {:decisions [6.5, 5.93] :objectives None}
# {:decisions [9.23, 14.67] :objectives None}
# {:decisions [7.98, 7.0] :objectives None}
# {:decisions [8.85, 15.53] :objectives None}
# {:decisions [3.89, 15.4] :objectives None}
# {:decisions [8.43, 11.75] :objectives None}
# {:decisions [7.57, 5.79] :objectives None}
# {:decisions [5.74, 14.48] :objectives None}
# {:decisions [9.72, 5.91] :objectives None}
# {:decisions [7.25, 10.9] :objectives None}
# {:decisions [3.89, 5.79] :objectives None}
# {:decisions [3.92, 13.77] :objectives None}
# {:decisions [4.78, 14.75] :objectives None}
# {:decisions [6.19, 17.55] :objectives None}
# {:decisions [7.61, 12.38] :objectives None}
# {:decisions [3.92, 5.51] :objectives None}
# {:decisions [7.71, 14.33] :objectives None}
# {:decisions [6.28, 18.04] :objectives None}
# {:decisions [6.82, 6.3] :objectives None}
# {:decisions [7.81, 10.97] :objectives None}
# {:decisions [9.44, 6.3] :objectives None}
# {:decisions [9.29, 12.95] :objectives None}
# {:decisions [6.66, 7.47] :objectives None}
# {:decisions [9.05, 3.45] :objectives None}
# {:decisions [4.76, 11.75] :objectives None}
# {:decisions [5.72, 11.77] :objectives None}
# {:decisions [7.28, 14.16] :objectives None}
# {:decisions [5.97, 7.93] :objectives None}
# {:decisions [6.19, 14.7] :objectives None}
# {:decisions [8.0, 14.48] :objectives None}
# {:decisions [8.43, 3.68] :objectives None}
# {:decisions [9.66, 19.89] :objectives None}
# {:decisions [4.88, 17.46] :objectives None}
# {:decisions [9.26, 18.11] :objectives None}
# {:decisions [8.53, 13.11] :objectives None}
# {:decisions [9.0, 14.7] :objectives None}
# {:decisions [6.05, 17.46] :objectives None}
# {:decisions [4.3, 12.95] :objectives None}
# {:decisions [6.92, 7.76] :objectives None}
# {:decisions [7.8, 15.53] :objectives None}
# {:decisions [9.0, 10.6] :objectives None}
# {:decisions [7.81, 6.3] :objectives None}
# {:decisions [8.32, 14.33] :objectives None}
# {:decisions [8.43, 9.24] :objectives None}
# {:decisions [8.53, 19.89] :objectives None}
# {:decisions [7.45, 13.77] :objectives None}
# {:decisions [9.7, 17.73] :objectives None}
# {:decisions [6.92, 17.44] :objectives None}
# {:decisions [8.53, 14.67] :objectives None}
# {:decisions [6.64, 14.16] :objectives None}
# {:decisions [6.87, 17.48] :objectives None}
# {:decisions [3.92, 16.01] :objectives None}
# {:decisions [7.03, 18.09] :objectives None}
# {:decisions [8.0, 13.11] :objectives None}
# {:decisions [6.19, 13.11] :objectives None}
# {:decisions [8.82, 18.22] :objectives None}
# {:decisions [5.08, 14.48] :objectives None}
# {:decisions [8.64, 14.86] :objectives None}
# {:decisions [8.82, 19.85] :objectives None}
# {:decisions [6.82, 18.87] :objectives None}
# {:decisions [7.56, 5.7] :objectives None}
# {:decisions [6.05, 6.3] :objectives None}
# {:decisions [8.32, 15.81] :objectives None}
# {:decisions [4.78, 17.46] :objectives None}
# {:decisions [6.92, 14.67] :objectives None}
# {:decisions [9.26, 11.77] :objectives None}
# {:decisions [9.54, 15.81] :objectives None}
# {:decisions [6.51, 3.68] :objectives None}
# {:decisions [9.0, 12.58] :objectives None}
# {:decisions [7.8, 15.98] :objectives None}
# {:decisions [6.84, 12.95] :objectives None}
# {:decisions [7.57, 14.7] :objectives None}
# {:decisions [8.52, 5.93] :objectives None}
# {:decisions [4.88, 16.55] :objectives None}
# {:decisions [6.87, 14.86] :objectives None}
# {:decisions [9.12, 3.45] :objectives None}
# {:decisions [9.05, 7.92] :objectives None}
# {:decisions [5.57, 17.44] :objectives None}
# {:decisions [7.25, 18.04] :objectives None}
# {:decisions [6.5, 3.45] :objectives None}
# {:decisions [7.08, 17.48] :objectives None}
# {:decisions [6.92, 16.81] :objectives None}
# {:decisions [8.53, 19.0] :objectives None}
# {:decisions [5.94, 15.53] :objectives None}
# {:decisions [6.5, 18.04] :objectives None}
# {:decisions [8.82, 5.81] :objectives None}
# {:decisions [9.26, 5.91] :objectives None}
# {:decisions [9.37, 14.48] :objectives None}
# {:decisions [7.56, 11.77] :objectives None}
# {:decisions [9.85, 14.48] :objectives None}
# {:decisions [5.57, 14.48] :objectives None}
# {:decisions [4.88, 12.58] :objectives None}
# {:decisions [6.62, 19.59] :objectives None}
# {:decisions [8.64, 19.69] :objectives None}
# .{:decisions [3.63, 12.57] :objectives None}
# {:decisions [3.92, 2.95] :objectives None}
# {:decisions [9.05, 18.87] :objectives None}
# {:decisions [8.32, 12.95] :objectives None}
# {:decisions [9.26, 13.77] :objectives None}
# {:decisions [7.95, 5.91] :objectives None}
# {:decisions [6.61, 10.85] :objectives None}
# {:decisions [7.98, 16.04] :objectives None}
# {:decisions [4.78, 7.93] :objectives None}
# {:decisions [6.19, 18.11] :objectives None}
# {:decisions [5.13, 11.42] :objectives None}
# {:decisions [7.95, 16.33] :objectives None}
# {:decisions [7.98, 5.43] :objectives None}
# {:decisions [7.57, 13.84] :objectives None}
# {:decisions [8.19, 2.95] :objectives None}
# {:decisions [3.69, 6.8] :objectives None}
# {:decisions [5.37, 6.8] :objectives None}
# {:decisions [7.81, 3.68] :objectives None}
# {:decisions [9.44, 16.33] :objectives None}
# {:decisions [7.71, 12.38] :objectives None}
# {:decisions [4.23, 10.9] :objectives None}
# {:decisions [6.19, 7.0] :objectives None}
# {:decisions [8.0, 14.81] :objectives None}
# {:decisions [5.13, 11.75] :objectives None}
# {:decisions [7.02, 7.0] :objectives None}
# {:decisions [3.89, 18.11] :objectives None}
# {:decisions [6.05, 3.47] :objectives None}
# {:decisions [4.76, 17.48] :objectives None}
# {:decisions [5.13, 14.48] :objectives None}
# {:decisions [5.66, 10.97] :objectives None}
# {:decisions [7.25, 17.48] :objectives None}
# {:decisions [6.87, 18.95] :objectives None}
# {:decisions [7.03, 4.23] :objectives None}
# {:decisions [9.26, 7.92] :objectives None}
# {:decisions [4.76, 13.39] :objectives None}
# {:decisions [7.57, 16.01] :objectives None}
# {:decisions [9.15, 11.42] :objectives None}
# {:decisions [5.57, 19.71] :objectives None}
# {:decisions [8.24, 14.48] :objectives None}
# {:decisions [5.08, 16.81] :objectives None}
# {:decisions [5.97, 17.0] :objectives None}
# {:decisions [8.82, 12.65] :objectives None}
# {:decisions [9.37, 15.81] :objectives None}
# {:decisions [5.08, 14.86] :objectives None}
# {:decisions [4.23, 11.42] :objectives None}
# {:decisions [6.61, 16.33] :objectives None}
# {:decisions [0.66, 17.47] :objectives None}
# {:decisions [9.26, 18.05] :objectives None}
# {:decisions [5.72, 11.42] :objectives None}
# {:decisions [4.31, 17.47] :objectives None}
# {:decisions [4.62, 19.89] :objectives None}
# {:decisions [4.31, 15.09] :objectives None}
# {:decisions [8.53, 17.73] :objectives None}
# {:decisions [9.37, 19.85] :objectives None}
# {:decisions [4.3, 15.53] :objectives None}
# {:decisions [8.02, 18.84] :objectives None}
# {:decisions [8.53, 8.16] :objectives None}
# {:decisions [8.02, 17.0] :objectives None}
# {:decisions [6.62, 19.71] :objectives None}
# {:decisions [5.37, 17.73] :objectives None}
# {:decisions [4.23, 18.01] :objectives None}
# {:decisions [5.08, 14.81] :objectives None}
# {:decisions [9.29, 14.67] :objectives None}
# {:decisions [5.66, 17.68] :objectives None}
# {:decisions [5.72, 7.14] :objectives None}
# {:decisions [8.24, 16.33] :objectives None}
# {:decisions [8.02, 7.92] :objectives None}
# {:decisions [7.8, 10.97] :objectives None}
# {:decisions [8.64, 14.81] :objectives None}
# {:decisions [8.82, 12.38] :objectives None}
# {:decisions [7.08, 13.77] :objectives None}
# {:decisions [3.63, 2.72] :objectives None}
# {:decisions [7.08, 10.35] :objectives None}
# {:decisions [9.26, 10.85] :objectives None}
# {:decisions [5.72, 7.92] :objectives None}
# {:decisions [8.64, 2.72] :objectives None}
# {:decisions [9.26, 15.4] :objectives None}
# {:decisions [3.92, 3.45] :objectives None}
# {:decisions [6.64, 6.49] :objectives None}
# {:decisions [7.03, 17.46] :objectives None}
# {:decisions [5.74, 8.16] :objectives None}
# {:decisions [5.37, 10.35] :objectives None}
# {:decisions [9.29, 12.47] :objectives None}
# {:decisions [9.7, 4.32] :objectives None}
# {:decisions [8.82, 9.24] :objectives None}
# {:decisions [4.94, 3.45] :objectives None}
# {:decisions [5.72, 17.73] :objectives None}
# {:decisions [7.61, 11.75] :objectives None}
# {:decisions [9.26, 15.81] :objectives None}
# {:decisions [8.82, 10.6] :objectives None}
# {:decisions [7.02, 15.81] :objectives None}
# {:decisions [4.53, 16.72] :objectives None}
# {:decisions [5.66, 19.85] :objectives None}
# {:decisions [5.94, 0.47] :objectives None}
# {:decisions [7.81, 18.84] :objectives None}
# {:decisions [3.97, 16.01] :objectives None}
# {:decisions [9.0, 5.91] :objectives None}
# {:decisions [9.44, 12.47] :objectives None}
# {:decisions [5.13, 7.47] :objectives None}
# {:decisions [3.69, 15.09] :objectives None}
# .{:decisions [6.05, 17.55] :objectives None}
# {:decisions [8.95, 17.46] :objectives None}
# {:decisions [8.95, 18.95] :objectives None}
# {:decisions [9.26, 18.04] :objectives None}
# {:decisions [4.53, 2.95] :objectives None}
# {:decisions [7.08, 10.85] :objectives None}
# {:decisions [9.29, 6.49] :objectives None}
# {:decisions [5.74, 16.72] :objectives None}
# {:decisions [5.54, 6.49] :objectives None}
# {:decisions [6.05, 14.16] :objectives None}
# {:decisions [7.57, 19.85] :objectives None}
# {:decisions [3.63, 17.46] :objectives None}
# {:decisions [7.61, 14.86] :objectives None}
# {:decisions [5.57, 8.72] :objectives None}
# {:decisions [5.05, 5.81] :objectives None}
# {:decisions [7.45, 5.79] :objectives None}
# {:decisions [5.08, 11.77] :objectives None}
# {:decisions [8.52, 12.57] :objectives None}
# {:decisions [9.78, 17.55] :objectives None}
# {:decisions [9.7, 6.3] :objectives None}
# {:decisions [7.81, 12.38] :objectives None}
# {:decisions [9.78, 11.75] :objectives None}
# {:decisions [7.95, 17.53] :objectives None}
# {:decisions [8.52, 14.48] :objectives None}
# {:decisions [6.92, 18.05] :objectives None}
# {:decisions [4.94, 10.6] :objectives None}
# {:decisions [7.71, 4.23] :objectives None}
# {:decisions [3.69, 10.9] :objectives None}
# {:decisions [6.5, 14.75] :objectives None}
# {:decisions [4.62, 19.0] :objectives None}
# {:decisions [9.78, 5.81] :objectives None}
# {:decisions [8.52, 17.46] :objectives None}
# {:decisions [7.74, 17.73] :objectives None}
# {:decisions [4.3, 8.16] :objectives None}
# {:decisions [8.82, 9.24] :objectives None}
# {:decisions [9.23, 14.75] :objectives None}
# {:decisions [8.17, 7.56] :objectives None}
# {:decisions [7.02, 13.86] :objectives None}
# {:decisions [4.88, 14.67] :objectives None}
# {:decisions [4.62, 17.44] :objectives None}
# {:decisions [7.57, 16.81] :objectives None}
# {:decisions [3.97, 17.44] :objectives None}
# {:decisions [8.52, 17.47] :objectives None}
# {:decisions [9.23, 12.38] :objectives None}
# {:decisions [7.3, 7.92] :objectives None}
# {:decisions [9.12, 3.45] :objectives None}
# {:decisions [3.63, 19.89] :objectives None}
# {:decisions [6.5, 5.91] :objectives None}
# {:decisions [6.19, 17.53] :objectives None}
# {:decisions [3.69, 2.72] :objectives None}
# {:decisions [8.17, 18.11] :objectives None}
# {:decisions [3.69, 17.0] :objectives None}
# {:decisions [4.3, 10.9] :objectives None}
# {:decisions [6.5, 7.56] :objectives None}
# {:decisions [4.47, 8.53] :objectives None}
# {:decisions [6.28, 5.7] :objectives None}
# {:decisions [6.28, 10.6] :objectives None}
# {:decisions [6.87, 13.86] :objectives None}
# {:decisions [6.66, 9.24] :objectives None}
# {:decisions [5.94, 10.97] :objectives None}
# {:decisions [5.13, 7.56] :objectives None}
# {:decisions [3.89, 11.42] :objectives None}
# {:decisions [8.32, 15.53] :objectives None}
# {:decisions [7.57, 19.59] :objectives None}
# {:decisions [9.7, 16.81] :objectives None}
# {:decisions [6.27, 8.16] :objectives None}
# {:decisions [8.53, 14.67] :objectives None}
# {:decisions [8.17, 17.47] :objectives None}
# {:decisions [3.63, 14.86] :objectives None}
# {:decisions [6.72, 13.86] :objectives None}
# {:decisions [4.47, 6.49] :objectives None}
# {:decisions [5.05, 15.17] :objectives None}
# {:decisions [7.8, 6.49] :objectives None}
# {:decisions [8.53, 16.01] :objectives None}
# {:decisions [7.57, 12.47] :objectives None}
# {:decisions [3.63, 10.11] :objectives None}
# {:decisions [8.52, 13.84] :objectives None}
# {:decisions [5.54, 9.24] :objectives None}
# {:decisions [9.29, 15.11] :objectives None}
# {:decisions [7.45, 16.01] :objectives None}
# {:decisions [6.87, 14.75] :objectives None}
# {:decisions [7.56, 10.9] :objectives None}
# {:decisions [7.71, 18.04] :objectives None}
# {:decisions [7.61, 18.95] :objectives None}
# {:decisions [7.95, 19.89] :objectives None}
# {:decisions [6.82, 5.81] :objectives None}
# {:decisions [3.63, 12.95] :objectives None}
# {:decisions [7.03, 16.55] :objectives None}
# {:decisions [6.5, 16.72] :objectives None}
# {:decisions [6.19, 14.67] :objectives None}
# {:decisions [8.0, 17.0] :objectives None}
# {:decisions [8.02, 19.89] :objectives None}
# {:decisions [7.71, 7.92] :objectives None}
# {:decisions [5.08, 18.11] :objectives None}
# {:decisions [5.74, 16.81] :objectives None}
# {:decisions [7.03, 10.9] :objectives None}
# {:decisions [7.71, 7.92] :objectives None}
# {:decisions [5.94, 17.44] :objectives None}
# {:decisions [8.19, 18.11] :objectives None}
# {:decisions [7.32, 6.8] :objectives None}
# .{:decisions [7.3, 8.72] :objectives None}
# {:decisions [5.13, 18.95] :objectives None}
# {:decisions [9.29, 5.91] :objectives None}
# {:decisions [8.02, 18.05] :objectives None}
# {:decisions [9.37, 13.86] :objectives None}
# {:decisions [9.12, 5.43] :objectives None}
# {:decisions [5.37, 16.33] :objectives None}
# {:decisions [6.5, 9.57] :objectives None}
# {:decisions [6.35, 17.47] :objectives None}
# {:decisions [4.94, 17.53] :objectives None}
# {:decisions [8.32, 16.81] :objectives None}
# {:decisions [8.52, 14.67] :objectives None}
# {:decisions [4.76, 14.39] :objectives None}
# {:decisions [7.45, 6.49] :objectives None}
# {:decisions [3.69, 12.95] :objectives None}
# {:decisions [7.57, 7.5] :objectives None}
# {:decisions [9.7, 11.42] :objectives None}
# {:decisions [8.52, 18.05] :objectives None}
# {:decisions [8.85, 17.42] :objectives None}
# {:decisions [6.51, 18.11] :objectives None}
# {:decisions [6.08, 12.65] :objectives None}
# {:decisions [8.02, 15.53] :objectives None}
# {:decisions [7.81, 17.73] :objectives None}
# {:decisions [6.08, 14.48] :objectives None}
# {:decisions [8.52, 8.53] :objectives None}
# {:decisions [8.0, 10.11] :objectives None}
# {:decisions [9.26, 16.72] :objectives None}
# {:decisions [9.15, 17.48] :objectives None}
# {:decisions [4.53, 5.51] :objectives None}
# {:decisions [7.02, 10.85] :objectives None}
# {:decisions [5.72, 14.75] :objectives None}
# {:decisions [8.24, 14.48] :objectives None}
# {:decisions [7.32, 15.53] :objectives None}
# {:decisions [9.85, 19.0] :objectives None}
# {:decisions [6.92, 17.42] :objectives None}
# {:decisions [9.7, 16.55] :objectives None}
# {:decisions [6.51, 6.8] :objectives None}
# {:decisions [5.5, 9.24] :objectives None}
# {:decisions [5.57, 10.11] :objectives None}
# {:decisions [4.76, 17.53] :objectives None}
# {:decisions [8.19, 7.0] :objectives None}
# {:decisions [8.02, 15.53] :objectives None}
# {:decisions [5.13, 3.45] :objectives None}
# {:decisions [8.17, 5.79] :objectives None}
# {:decisions [8.85, 10.9] :objectives None}
# {:decisions [4.3, 15.81] :objectives None}
# {:decisions [6.64, 2.95] :objectives None}
# {:decisions [4.78, 16.04] :objectives None}
# {:decisions [3.69, 13.11] :objectives None}
# {:decisions [9.54, 19.71] :objectives None}
# {:decisions [4.3, 3.47] :objectives None}
# {:decisions [8.17, 5.51] :objectives None}
# {:decisions [8.52, 12.95] :objectives None}
# {:decisions [8.64, 18.04] :objectives None}
# {:decisions [5.37, 10.35] :objectives None}
# {:decisions [6.72, 17.68] :objectives None}
# {:decisions [4.3, 17.55] :objectives None}
# {:decisions [6.87, 10.11] :objectives None}
# {:decisions [9.44, 14.39] :objectives None}
# {:decisions [8.17, 16.72] :objectives None}
# {:decisions [5.74, 12.57] :objectives None}
# {:decisions [7.81, 10.9] :objectives None}
# {:decisions [9.0, 11.77] :objectives None}
# {:decisions [9.72, 14.86] :objectives None}
# {:decisions [8.0, 7.56] :objectives None}
# {:decisions [9.29, 15.09] :objectives None}
# {:decisions [8.24, 11.42] :objectives None}
# {:decisions [9.23, 18.84] :objectives None}
# {:decisions [4.99, 15.11] :objectives None}
# {:decisions [6.72, 8.72] :objectives None}
# {:decisions [9.72, 13.11] :objectives None}
# {:decisions [8.0, 17.47] :objectives None}
# {:decisions [9.72, 10.11] :objectives None}
# {:decisions [9.44, 7.47] :objectives None}
# {:decisions [8.19, 9.57] :objectives None}
# {:decisions [4.3, 17.44] :objectives None}
# {:decisions [8.0, 17.46] :objectives None}
# {:decisions [5.54, 19.71] :objectives None}
# {:decisions [3.92, 18.01] :objectives None}
# {:decisions [9.26, 5.81] :objectives None}
# {:decisions [9.54, 12.95] :objectives None}
# {:decisions [4.53, 12.47] :objectives None}
# {:decisions [5.5, 18.05] :objectives None}
# {:decisions [5.41, 12.47] :objectives None}
# {:decisions [7.32, 18.87] :objectives None}
# {:decisions [4.76, 7.93] :objectives None}
# {:decisions [9.23, 7.47] :objectives None}
# {:decisions [7.08, 7.93] :objectives None}
# {:decisions [5.74, 15.4] :objectives None}
# {:decisions [9.66, 10.11] :objectives None}
# {:decisions [8.98, 17.48] :objectives None}
# {:decisions [8.98, 10.6] :objectives None}
# {:decisions [5.41, 18.04] :objectives None}
# {:decisions [4.99, 19.0] :objectives None}
# {:decisions [8.52, 14.48] :objectives None}
# {:decisions [5.37, 3.47] :objectives None}
# {:decisions [3.92, 17.55] :objectives None}
# {:decisions [3.97, 14.75] :objectives None}
# {:decisions [8.85, 17.68] :objectives None}
# {:decisions [5.41, 15.81] :objectives None}
# .{:decisions [3.97, 16.55] :objectives None}
# {:decisions [6.64, 5.7] :objectives None}
# {:decisions [6.08, 7.56] :objectives None}
# {:decisions [6.87, 17.73] :objectives None}
# {:decisions [9.15, 10.9] :objectives None}
# {:decisions [7.71, 19.89] :objectives None}
# {:decisions [4.88, 14.81] :objectives None}
# {:decisions [4.88, 7.47] :objectives None}
# {:decisions [7.8, 15.81] :objectives None}
# {:decisions [5.97, 19.69] :objectives None}
# {:decisions [3.97, 13.86] :objectives None}
# {:decisions [4.94, 10.85] :objectives None}
# {:decisions [6.92, 14.7] :objectives None}
# {:decisions [9.23, 14.86] :objectives None}
# {:decisions [7.45, 18.05] :objectives None}
# {:decisions [7.55, 5.7] :objectives None}
# {:decisions [6.92, 12.47] :objectives None}
# {:decisions [3.63, 12.57] :objectives None}
# {:decisions [4.47, 5.91] :objectives None}
# {:decisions [8.43, 6.8] :objectives None}
# {:decisions [5.08, 12.57] :objectives None}
# {:decisions [4.99, 5.7] :objectives None}
# {:decisions [6.82, 5.61] :objectives None}
# {:decisions [6.92, 15.98] :objectives None}
# {:decisions [6.92, 7.14] :objectives None}
# {:decisions [9.78, 18.05] :objectives None}
# {:decisions [9.66, 10.6] :objectives None}
# {:decisions [8.64, 14.48] :objectives None}
# {:decisions [4.65, 11.75] :objectives None}
# {:decisions [7.25, 16.72] :objectives None}
# {:decisions [4.88, 5.61] :objectives None}
# {:decisions [9.78, 10.9] :objectives None}
# {:decisions [7.8, 17.68] :objectives None}
# {:decisions [5.74, 6.49] :objectives None}
# {:decisions [9.12, 17.55] :objectives None}
# {:decisions [6.5, 16.33] :objectives None}
# {:decisions [4.23, 17.53] :objectives None}
# {:decisions [9.44, 14.81] :objectives None}
# {:decisions [4.76, 18.04] :objectives None}
# {:decisions [6.35, 14.75] :objectives None}
# {:decisions [8.82, 7.56] :objectives None}
# {:decisions [7.74, 16.72] :objectives None}
# {:decisions [9.44, 5.93] :objectives None}
# {:decisions [9.23, 19.85] :objectives None}
# {:decisions [4.3, 6.49] :objectives None}
# {:decisions [8.82, 5.93] :objectives None}
# {:decisions [6.5, 14.75] :objectives None}
# {:decisions [8.64, 12.57] :objectives None}
# {:decisions [1.5, 6.49] :objectives None}
# {:decisions [6.19, 18.84] :objectives None}
# {:decisions [6.87, 5.91] :objectives None}
# {:decisions [6.87, 10.9] :objectives None}
# {:decisions [6.08, 7.76] :objectives None}
# {:decisions [9.12, 15.98] :objectives None}
# {:decisions [6.72, 12.95] :objectives None}
# {:decisions [6.27, 17.73] :objectives None}
# {:decisions [6.19, 9.57] :objectives None}
# {:decisions [4.65, 8.72] :objectives None}
# {:decisions [6.82, 19.69] :objectives None}
# {:decisions [8.02, 18.84] :objectives None}
# {:decisions [9.44, 7.0] :objectives None}
# {:decisions [5.54, 18.87] :objectives None}
# {:decisions [9.85, 17.49] :objectives None}
# {:decisions [9.72, 18.22] :objectives None}
# {:decisions [9.44, 7.0] :objectives None}
# {:decisions [4.47, 7.0] :objectives None}
# {:decisions [9.26, 18.11] :objectives None}
# {:decisions [5.13, 19.0] :objectives None}
# {:decisions [9.0, 15.11] :objectives None}
# {:decisions [9.44, 18.05] :objectives None}
# {:decisions [7.28, 12.95] :objectives None}
# {:decisions [8.17, 17.48] :objectives None}
# {:decisions [8.85, 14.75] :objectives None}
# {:decisions [9.0, 10.6] :objectives None}
# {:decisions [4.62, 18.05] :objectives None}
# {:decisions [8.64, 7.5] :objectives None}
# {:decisions [4.76, 18.22] :objectives None}
# {:decisions [9.37, 2.72] :objectives None}
# {:decisions [7.45, 14.75] :objectives None}
# {:decisions [4.31, 6.49] :objectives None}
# {:decisions [8.82, 7.56] :objectives None}
# {:decisions [7.25, 12.47] :objectives None}
# {:decisions [9.54, 7.92] :objectives None}
# {:decisions [8.0, 13.77] :objectives None}
# {:decisions [8.02, 16.55] :objectives None}
# {:decisions [7.32, 3.45] :objectives None}
# {:decisions [8.82, 10.9] :objectives None}
# {:decisions [6.51, 2.72] :objectives None}
# {:decisions [8.98, 19.69] :objectives None}
# {:decisions [8.53, 18.04] :objectives None}
# {:decisions [7.71, 12.58] :objectives None}
# {:decisions [6.28, 16.72] :objectives None}
# {:decisions [9.12, 5.43] :objectives None}
# {:decisions [5.94, 5.79] :objectives None}
# {:decisions [5.05, 12.47] :objectives None}
# {:decisions [7.25, 15.98] :objectives None}
# {:decisions [8.17, 2.72] :objectives None}
# {:decisions [7.81, 12.65] :objectives None}
# {:decisions [9.26, 5.81] :objectives None}
# {:decisions [6.51, 13.11] :objectives None}
# .{:decisions [9.05, 5.81] :objectives None}
# {:decisions [5.74, 13.11] :objectives None}
# {:decisions [4.88, 19.59] :objectives None}
# {:decisions [7.81, 7.56] :objectives None}
# {:decisions [6.66, 3.47] :objectives None}
# {:decisions [9.44, 15.11] :objectives None}
# {:decisions [4.76, 7.92] :objectives None}
# {:decisions [5.13, 15.1] :objectives None}
# {:decisions [7.8, 12.65] :objectives None}
# {:decisions [8.32, 15.4] :objectives None}
# {:decisions [6.28, 3.47] :objectives None}
# {:decisions [6.82, 12.65] :objectives None}
# {:decisions [7.98, 7.47] :objectives None}
# {:decisions [7.98, 18.05] :objectives None}
# {:decisions [7.81, 7.92] :objectives None}
# {:decisions [9.44, 14.48] :objectives None}
# {:decisions [9.43, 12.58] :objectives None}
# {:decisions [8.02, 3.68] :objectives None}
# {:decisions [5.72, 13.86] :objectives None}
# {:decisions [6.62, 15.81] :objectives None}
# {:decisions [6.92, 6.8] :objectives None}
# {:decisions [6.82, 15.09] :objectives None}
# {:decisions [8.95, 15.98] :objectives None}
# {:decisions [6.87, 16.55] :objectives None}
# {:decisions [9.26, 8.16] :objectives None}
# {:decisions [9.12, 2.72] :objectives None}
# {:decisions [8.85, 17.55] :objectives None}
# {:decisions [9.66, 9.24] :objectives None}
# {:decisions [6.87, 18.84] :objectives None}
# {:decisions [9.0, 13.84] :objectives None}
# {:decisions [8.53, 13.77] :objectives None}
# {:decisions [9.43, 11.42] :objectives None}
# {:decisions [7.57, 17.55] :objectives None}
# {:decisions [7.28, 10.9] :objectives None}
# {:decisions [9.66, 14.67] :objectives None}
# {:decisions [6.92, 7.76] :objectives None}
# {:decisions [6.62, 5.7] :objectives None}
# {:decisions [7.3, 14.86] :objectives None}
# {:decisions [5.08, 18.04] :objectives None}
# {:decisions [5.57, 17.46] :objectives None}
# {:decisions [5.54, 7.56] :objectives None}
# {:decisions [7.28, 16.55] :objectives None}
# {:decisions [6.19, 14.39] :objectives None}
# {:decisions [7.98, 3.68] :objectives None}
# {:decisions [4.78, 5.51] :objectives None}
# {:decisions [4.62, 7.14] :objectives None}
# {:decisions [6.05, 18.84] :objectives None}
# {:decisions [5.13, 12.58] :objectives None}
# {:decisions [6.28, 12.38] :objectives None}
# {:decisions [6.08, 15.81] :objectives None}
# {:decisions [5.74, 17.49] :objectives None}
# {:decisions [3.97, 7.14] :objectives None}
# {:decisions [5.37, 11.77] :objectives None}
# {:decisions [8.52, 17.73] :objectives None}
# {:decisions [8.0, 8.72] :objectives None}
# {:decisions [4.31, 13.84] :objectives None}
# {:decisions [6.87, 7.5] :objectives None}
# {:decisions [7.03, 18.04] :objectives None}
# {:decisions [7.95, 13.77] :objectives None}
# {:decisions [8.19, 10.35] :objectives None}
# {:decisions [7.28, 14.86] :objectives None}
# {:decisions [7.71, 17.55] :objectives None}
# {:decisions [7.98, 16.01] :objectives None}
# {:decisions [8.19, 17.73] :objectives None}
# {:decisions [8.52, 3.45] :objectives None}
# {:decisions [4.53, 18.11] :objectives None}
# {:decisions [6.51, 17.48] :objectives None}
# {:decisions [9.37, 12.38] :objectives None}
# {:decisions [8.52, 15.4] :objectives None}
# {:decisions [5.08, 7.76] :objectives None}
# {:decisions [7.03, 7.0] :objectives None}
# {:decisions [8.43, 19.59] :objectives None}
# {:decisions [9.29, 7.14] :objectives None}
# {:decisions [9.05, 11.75] :objectives None}
# {:decisions [7.95, 7.92] :objectives None}
# {:decisions [6.87, 10.6] :objectives None}
# {:decisions [5.97, 17.46] :objectives None}
# {:decisions [9.66, 8.72] :objectives None}
# {:decisions [6.51, 7.93] :objectives None}
# {:decisions [6.28, 9.24] :objectives None}
# {:decisions [5.08, 16.33] :objectives None}
# {:decisions [5.66, 11.42] :objectives None}
# {:decisions [9.12, 7.5] :objectives None}
# {:decisions [6.92, 16.04] :objectives None}
# {:decisions [8.98, 12.95] :objectives None}
# {:decisions [6.66, 14.86] :objectives None}
# {:decisions [4.47, 17.73] :objectives None}
# {:decisions [6.72, 19.69] :objectives None}
# {:decisions [6.05, 19.69] :objectives None}
# {:decisions [7.95, 13.77] :objectives None}
# {:decisions [4.23, 18.95] :objectives None}
# {:decisions [7.81, 8.53] :objectives None}
# {:decisions [6.28, 10.97] :objectives None}
# {:decisions [4.94, 3.47] :objectives None}
# {:decisions [9.85, 16.55] :objectives None}
# {:decisions [6.51, 5.61] :objectives None}
# {:decisions [7.08, 10.9] :objectives None}
# {:decisions [7.32, 15.4] :objectives None}
# {:decisions [6.08, 12.38] :objectives None}
# {:decisions [9.0, 5.61] :objectives None}
# .{:decisions [7.95, 17.48] :objectives None}
# {:decisions [8.98, 5.51] :objectives None}
# ...
# {:decisions [8.32, 3.68] :objectives None}
# {:decisions [7.61, 8.53] :objectives None}
# {:decisions [4.78, 18.09] :objectives None}
# {:decisions [7.57, 12.58] :objectives None}
# {:decisions [9.0, 19.69] :objectives None}
# {:decisions [6.51, 10.74] :objectives None}
# {:decisions [7.95, 17.0] :objectives None}
# {:decisions [9.15, 10.6] :objectives None}
# {:decisions [5.94, 7.93] :objectives None}
# {:decisions [8.82, 18.95] :objectives None}
# {:decisions [4.88, 17.68] :objectives None}
# {:decisions [7.45, 9.24] :objectives None}
# {:decisions [9.54, 17.68] :objectives None}
# {:decisions [8.98, 17.46] :objectives None}
# {:decisions [6.66, 14.67] :objectives None}
# {:decisions [8.02, 5.91] :objectives None}
# {:decisions [3.97, 13.86] :objectives None}
# {:decisions [7.32, 17.53] :objectives None}
# {:decisions [6.61, 15.09] :objectives None}
# {:decisions [9.43, 3.47] :objectives None}
# {:decisions [5.94, 13.39] :objectives None}
# {:decisions [8.82, 18.01] :objectives None}
# {:decisions [7.61, 19.89] :objectives None}
# {:decisions [4.88, 8.72] :objectives None}
# {:decisions [6.61, 14.16] :objectives None}
# {:decisions [9.37, 13.86] :objectives None}
# {:decisions [9.29, 2.95] :objectives None}
# {:decisions [8.02, 12.58] :objectives None}
# {:decisions [6.28, 17.47] :objectives None}
# {:decisions [3.97, 12.57] :objectives None}
# {:decisions [7.74, 12.47] :objectives None}
# {:decisions [6.62, 15.98] :objectives None}
# {:decisions [9.0, 11.77] :objectives None}
# {:decisions [8.85, 10.35] :objectives None}
# {:decisions [3.97, 7.14] :objectives None}
# {:decisions [7.98, 14.48] :objectives None}
# {:decisions [8.32, 14.48] :objectives None}
# {:decisions [5.13, 12.38] :objectives None}
# {:decisions [4.62, 8.16] :objectives None}
# {:decisions [9.12, 14.39] :objectives None}
# {:decisions [5.05, 19.71] :objectives None}
# {:decisions [5.74, 17.49] :objectives None}
# {:decisions [6.08, 8.16] :objectives None}
# {:decisions [5.37, 15.81] :objectives None}
# {:decisions [4.99, 5.93] :objectives None}
# {:decisions [7.95, 7.93] :objectives None}
# {:decisions [9.85, 2.72] :objectives None}
# {:decisions [8.0, 6.5] :objectives None}
# {:decisions [9.12, 7.76] :objectives None}
# {:decisions [7.74, 15.98] :objectives None}
# {:decisions [6.28, 8.53] :objectives None}
# {:decisions [9.37, 18.22] :objectives None}
# {:decisions [6.05, 11.75] :objectives None}
# {:decisions [8.02, 16.01] :objectives None}
# {:decisions [4.88, 13.84] :objectives None}
# {:decisions [5.05, 15.98] :objectives None}
# {:decisions [5.66, 19.0] :objectives None}
# {:decisions [9.78, 18.01] :objectives None}
# {:decisions [6.61, 12.57] :objectives None}
# {:decisions [9.54, 12.65] :objectives None}
# {:decisions [9.26, 5.7] :objectives None}
# {:decisions [4.99, 17.55] :objectives None}
# {:decisions [9.15, 18.09] :objectives None}
# {:decisions [5.41, 18.01] :objectives None}
# {:decisions [4.94, 7.0] :objectives None}
# {:decisions [7.32, 18.04] :objectives None}
# {:decisions [7.08, 9.24] :objectives None}
# .{:decisions [6.5, 17.46] :objectives None}
# {:decisions [6.51, 11.77] :objectives None}
# {:decisions [9.26, 17.48] :objectives None}
# {:decisions [3.97, 10.9] :objectives None}
# {:decisions [4.23, 7.93] :objectives None}
# {:decisions [9.29, 18.22] :objectives None}
# {:decisions [9.26, 12.47] :objectives None}
# {:decisions [7.08, 14.81] :objectives None}
# {:decisions [6.05, 15.81] :objectives None}
# {:decisions [7.03, 18.01] :objectives None}
# {:decisions [7.3, 10.9] :objectives None}
# {:decisions [4.94, 15.17] :objectives None}
# {:decisions [7.57, 17.73] :objectives None}
# {:decisions [7.81, 7.14] :objectives None}
# {:decisions [4.94, 9.24] :objectives None}
# {:decisions [6.51, 3.45] :objectives None}
# {:decisions [8.19, 15.98] :objectives None}
# {:decisions [6.35, 7.14] :objectives None}
# {:decisions [5.72, 5.61] :objectives None}
# {:decisions [6.87, 14.75] :objectives None}
# {:decisions [9.37, 4.23] :objectives None}
# {:decisions [9.44, 19.69] :objectives None}
# {:decisions [4.62, 18.09] :objectives None}
# {:decisions [9.29, 6.3] :objectives None}
# {:decisions [5.72, 16.72] :objectives None}
# {:decisions [4.78, 14.48] :objectives None}
# {:decisions [5.37, 7.92] :objectives None}
# {:decisions [5.41, 10.9] :objectives None}
# {:decisions [9.85, 7.76] :objectives None}
# {:decisions [9.43, 10.6] :objectives None}
# {:decisions [8.52, 14.7] :objectives None}
# {:decisions [8.32, 9.24] :objectives None}
# {:decisions [5.94, 12.57] :objectives None}
# {:decisions [9.43, 16.81] :objectives None}
# {:decisions [4.47, 4.23] :objectives None}
# {:decisions [9.44, 17.53] :objectives None}
# {:decisions [3.89, 13.84] :objectives None}
# {:decisions [8.0, 14.81] :objectives None}
# {:decisions [8.19, 14.48] :objectives None}
# {:decisions [7.32, 2.72] :objectives None}
# {:decisions [7.45, 12.65] :objectives None}
# {:decisions [4.65, 15.81] :objectives None}
# {:decisions [9.26, 14.48] :objectives None}
# {:decisions [9.85, 16.04] :objectives None}
# {:decisions [4.23, 6.3] :objectives None}
# {:decisions [6.87, 8.09] :objectives None}
# {:decisions [6.87, 15.17] :objectives None}
# {:decisions [6.87, 10.11] :objectives None}
# {:decisions [7.95, 3.38] :objectives None}
# {:decisions [8.98, 7.47] :objectives None}
# {:decisions [9.26, 7.56] :objectives None}
# {:decisions [6.27, 14.86] :objectives None}
# {:decisions [6.92, 16.72] :objectives None}
# {:decisions [6.28, 16.01] :objectives None}
# {:decisions [5.74, 12.57] :objectives None}
# {:decisions [6.08, 17.73] :objectives None}
# {:decisions [8.82, 18.87] :objectives None}
# {:decisions [9.12, 7.0] :objectives None}
# {:decisions [7.81, 15.09] :objectives None}
# {:decisions [6.72, 15.11] :objectives None}
# {:decisions [7.81, 3.47] :objectives None}
# {:decisions [9.05, 5.79] :objectives None}
# {:decisions [9.26, 6.3] :objectives None}
# {:decisions [9.43, 17.68] :objectives None}
# {:decisions [8.82, 3.45] :objectives None}
# {:decisions [7.74, 7.0] :objectives None}
# {:decisions [8.95, 18.05] :objectives None}
# {:decisions [8.95, 11.77] :objectives None}
# {:decisions [4.99, 2.72] :objectives None}
# {:decisions [9.15, 14.86] :objectives None}
# {:decisions [7.3, 14.16] :objectives None}
# {:decisions [8.24, 10.97] :objectives None}
# {:decisions [4.31, 3.47] :objectives None}
# {:decisions [8.43, 14.48] :objectives None}
# {:decisions [6.05, 15.09] :objectives None}
# {:decisions [5.57, 10.35] :objectives None}
# {:decisions [5.08, 19.89] :objectives None}
# {:decisions [8.82, 15.11] :objectives None}
# {:decisions [5.37, 7.93] :objectives None}
# {:decisions [6.92, 19.85] :objectives None}
# {:decisions [7.74, 15.09] :objectives None}
# {:decisions [4.53, 17.73] :objectives None}
# {:decisions [9.44, 15.98] :objectives None}
# {:decisions [5.74, 15.53] :objectives None}
# {:decisions [8.64, 16.81] :objectives None}
# {:decisions [9.85, 17.68] :objectives None}
# {:decisions [4.3, 18.04] :objectives None}
# {:decisions [4.31, 18.04] :objectives None}
# {:decisions [5.66, 5.59] :objectives None}
# {:decisions [9.37, 5.51] :objectives None}
# {:decisions [6.08, 16.01] :objectives None}
# {:decisions [6.61, 5.61] :objectives None}
# {:decisions [6.66, 6.3] :objectives None}
# {:decisions [5.5, 18.11] :objectives None}
# {:decisions [7.28, 18.01] :objectives None}
# {:decisions [6.61, 19.71] :objectives None}
# {:decisions [7.61, 18.01] :objectives None}
# {:decisions [9.12, 14.48] :objectives None}
# {:decisions [3.89, 8.72] :objectives None}
# {:decisions [9.78, 8.16] :objectives None}
# .{:decisions [9.54, 18.05] :objectives None}
# {:decisions [8.24, 10.85] :objectives None}
# {:decisions [7.61, 17.49] :objectives None}
# {:decisions [6.62, 17.47] :objectives None}
# {:decisions [8.19, 13.39] :objectives None}
# {:decisions [8.52, 10.97] :objectives None}
# {:decisions [7.25, 15.17] :objectives None}
# {:decisions [6.72, 17.46] :objectives None}
# {:decisions [6.66, 11.77] :objectives None}
# {:decisions [4.88, 7.09] :objectives None}
# {:decisions [7.81, 12.47] :objectives None}
# {:decisions [4.23, 16.01] :objectives None}
# {:decisions [9.44, 16.04] :objectives None}
# {:decisions [6.27, 7.56] :objectives None}
# {:decisions [6.72, 16.04] :objectives None}
# {:decisions [6.92, 7.0] :objectives None}
# {:decisions [6.87, 17.53] :objectives None}
# {:decisions [7.74, 19.85] :objectives None}
# {:decisions [7.28, 10.11] :objectives None}
# {:decisions [5.72, 10.35] :objectives None}
# {:decisions [5.94, 8.16] :objectives None}
# {:decisions [7.81, 14.48] :objectives None}
# {:decisions [6.14, 2.95] :objectives None}
# {:decisions [5.05, 9.24] :objectives None}
# {:decisions [8.53, 3.45] :objectives None}
# {:decisions [9.7, 18.05] :objectives None}
# {:decisions [6.64, 17.46] :objectives None}
# {:decisions [9.12, 18.87] :objectives None}
# {:decisions [8.19, 18.84] :objectives None}
# {:decisions [6.66, 17.28] :objectives None}
# {:decisions [8.98, 8.53] :objectives None}
# {:decisions [8.17, 15.98] :objectives None}
# {:decisions [8.24, 17.48] :objectives None}
# {:decisions [3.69, 3.47] :objectives None}
# {:decisions [7.56, 16.81] :objectives None}
# {:decisions [7.98, 12.58] :objectives None}
# {:decisions [3.89, 2.95] :objectives None}
# {:decisions [6.28, 18.95] :objectives None}
# {:decisions [9.29, 5.93] :objectives None}
# {:decisions [8.32, 12.38] :objectives None}
# {:decisions [7.97, 17.48] :objectives None}
# {:decisions [4.53, 15.53] :objectives None}
# {:decisions [7.28, 18.22] :objectives None}
# {:decisions [5.41, 14.48] :objectives None}
# {:decisions [9.44, 6.3] :objectives None}
# {:decisions [9.12, 13.86] :objectives None}
# {:decisions [9.7, 14.16] :objectives None}
# {:decisions [7.28, 5.51] :objectives None}
# {:decisions [9.26, 18.22] :objectives None}
# {:decisions [9.66, 12.57] :objectives None}
# {:decisions [3.89, 12.47] :objectives None}
# {:decisions [9.85, 14.33] :objectives None}
# {:decisions [4.31, 19.59] :objectives None}
# {:decisions [4.99, 6.8] :objectives None}
# {:decisions [6.5, 15.53] :objectives None}
# {:decisions [6.27, 12.38] :objectives None}
# {:decisions [4.3, 17.73] :objectives None}
# {:decisions [6.72, 19.69] :objectives None}
# {:decisions [5.13, 17.53] :objectives None}
# {:decisions [4.31, 7.14] :objectives None}
# {:decisions [6.82, 15.81] :objectives None}
# {:decisions [7.81, 4.23] :objectives None}
# {:decisions [4.76, 3.68] :objectives None}
# {:decisions [5.57, 12.58] :objectives None}
# {:decisions [9.78, 18.11] :objectives None}
# {:decisions [8.43, 5.7] :objectives None}
# {:decisions [8.17, 5.61] :objectives None}
# {:decisions [3.97, 17.68] :objectives None}
# {:decisions [8.43, 17.68] :objectives None}
# {:decisions [3.97, 5.51] :objectives None}
# {:decisions [6.87, 14.81] :objectives None}
# {:decisions [7.74, 17.46] :objectives None}
# {:decisions [9.26, 14.48] :objectives None}
# {:decisions [6.61, 8.53] :objectives None}
# {:decisions [5.13, 17.53] :objectives None}
# {:decisions [3.92, 18.95] :objectives None}
# {:decisions [7.74, 3.45] :objectives None}
# {:decisions [5.72, 18.22] :objectives None}
# {:decisions [7.08, 12.58] :objectives None}
# {:decisions [6.05, 17.42] :objectives None}
# {:decisions [6.19, 7.47] :objectives None}
# {:decisions [5.97, 6.49] :objectives None}
# {:decisions [7.61, 13.77] :objectives None}
# {:decisions [7.95, 2.72] :objectives None}
# {:decisions [7.25, 18.22] :objectives None}
# {:decisions [6.92, 7.92] :objectives None}
# {:decisions [9.78, 5.81] :objectives None}
# {:decisions [6.35, 13.84] :objectives None}
# {:decisions [7.98, 14.75] :objectives None}
# {:decisions [6.62, 17.49] :objectives None}
# {:decisions [5.13, 16.81] :objectives None}
# {:decisions [5.97, 7.93] :objectives None}
# {:decisions [8.24, 5.91] :objectives None}
# {:decisions [7.81, 10.97] :objectives None}
# {:decisions [6.27, 15.09] :objectives None}
# {:decisions [9.15, 15.98] :objectives None}
# {:decisions [9.54, 10.9] :objectives None}
# {:decisions [8.95, 17.47] :objectives None}
# {:decisions [8.52, 16.55] :objectives None}
# {:decisions [4.23, 5.61] :objectives None}
# .{:decisions [6.92, 6.3] :objectives None}
# {:decisions [5.74, 17.44] :objectives None}
# {:decisions [6.66, 7.0] :objectives None}
# {:decisions [7.74, 5.81] :objectives None}
# {:decisions [8.17, 18.95] :objectives None}
# {:decisions [3.69, 16.81] :objectives None}
# {:decisions [5.54, 7.14] :objectives None}
# {:decisions [3.89, 5.61] :objectives None}
# {:decisions [9.0, 17.0] :objectives None}
# {:decisions [6.51, 10.9] :objectives None}
# {:decisions [7.08, 8.16] :objectives None}
# {:decisions [6.5, 17.53] :objectives None}
# {:decisions [4.3, 6.3] :objectives None}
# {:decisions [6.27, 18.01] :objectives None}
# {:decisions [7.81, 12.58] :objectives None}
# {:decisions [3.69, 11.77] :objectives None}
# {:decisions [6.06, 16.55] :objectives None}
# {:decisions [3.63, 17.0] :objectives None}
# {:decisions [6.08, 17.48] :objectives None}
# {:decisions [8.02, 17.0] :objectives None}
# {:decisions [4.76, 10.6] :objectives None}
# {:decisions [8.85, 13.77] :objectives None}
# {:decisions [9.0, 13.77] :objectives None}
# {:decisions [6.5, 19.71] :objectives None}
# {:decisions [6.05, 7.76] :objectives None}
# {:decisions [6.66, 18.84] :objectives None}
# {:decisions [5.57, 5.93] :objectives None}
# {:decisions [8.43, 15.53] :objectives None}
# {:decisions [7.56, 13.84] :objectives None}
# {:decisions [7.57, 5.7] :objectives None}
# {:decisions [4.23, 15.4] :objectives None}
# {:decisions [8.95, 19.69] :objectives None}
# {:decisions [6.92, 7.14] :objectives None}
# {:decisions [5.74, 14.33] :objectives None}
# {:decisions [4.47, 7.5] :objectives None}
# {:decisions [4.62, 7.93] :objectives None}
# {:decisions [6.66, 12.58] :objectives None}
# {:decisions [4.65, 14.86] :objectives None}
# {:decisions [9.12, 16.81] :objectives None}
# {:decisions [8.98, 3.68] :objectives None}
# {:decisions [4.47, 7.93] :objectives None}
# {:decisions [9.15, 14.39] :objectives None}
# {:decisions [8.95, 18.84] :objectives None}
# {:decisions [7.74, 16.72] :objectives None}
# {:decisions [7.71, 2.95] :objectives None}
# {:decisions [7.57, 19.0] :objectives None}
# {:decisions [6.5, 14.39] :objectives None}
# {:decisions [4.99, 7.92] :objectives None}
# {:decisions [8.98, 13.77] :objectives None}
# {:decisions [8.82, 10.97] :objectives None}
# {:decisions [6.19, 10.97] :objectives None}
# {:decisions [9.78, 18.01] :objectives None}
# {:decisions [8.19, 3.68] :objectives None}
# {:decisions [4.76, 6.8] :objectives None}
# {:decisions [9.26, 10.9] :objectives None}
# {:decisions [7.81, 15.11] :objectives None}
# {:decisions [7.61, 12.47] :objectives None}
# {:decisions [3.89, 17.48] :objectives None}
# {:decisions [7.57, 15.81] :objectives None}
# {:decisions [4.99, 5.51] :objectives None}
# {:decisions [9.0, 12.47] :objectives None}
# {:decisions [8.17, 2.72] :objectives None}
# {:decisions [9.7, 15.17] :objectives None}
# {:decisions [5.94, 2.95] :objectives None}
# {:decisions [3.97, 12.38] :objectives None}
# {:decisions [6.19, 7.92] :objectives None}
# {:decisions [5.57, 19.0] :objectives None}
# {:decisions [8.53, 11.75] :objectives None}
# {:decisions [5.05, 15.11] :objectives None}
# {:decisions [3.89, 19.71] :objectives None}
# {:decisions [6.61, 5.91] :objectives None}
# {:decisions [7.56, 6.3] :objectives None}
# {:decisions [3.89, 17.48] :objectives None}
# {:decisions [8.52, 17.1] :objectives None}
# {:decisions [6.05, 3.47] :objectives None}
# {:decisions [6.64, 10.85] :objectives None}
# {:decisions [8.19, 16.01] :objectives None}
# {:decisions [8.02, 10.9] :objectives None}
# {:decisions [9.26, 12.9] :objectives None}
# {:decisions [8.24, 12.58] :objectives None}
# {:decisions [9.72, 6.49] :objectives None}
# {:decisions [5.74, 13.11] :objectives None}
# {:decisions [4.94, 2.72] :objectives None}
# {:decisions [5.41, 5.79] :objectives None}
# {:decisions [6.08, 13.39] :objectives None}
# {:decisions [3.92, 19.89] :objectives None}
# {:decisions [9.05, 6.3] :objectives None}
# {:decisions [5.13, 19.59] :objectives None}
# {:decisions [9.05, 13.84] :objectives None}
# {:decisions [4.65, 11.77] :objectives None}
# {:decisions [4.78, 19.71] :objectives None}
# {:decisions [6.92, 17.48] :objectives None}
# {:decisions [8.85, 13.11] :objectives None}
# {:decisions [6.19, 10.97] :objectives None}
# {:decisions [8.32, 19.89] :objectives None}
# {:decisions [8.82, 2.72] :objectives None}
# {:decisions [8.82, 17.42] :objectives None}
# {:decisions [9.7, 17.68] :objectives None}
# {:decisions [4.65, 18.22] :objectives None}
# {:decisions [9.29, 18.22] :objectives None}

# %% [markdown]
# Here is a sample output
# <img src="sample.png" width=300/>
